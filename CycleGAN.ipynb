# %% [markdown]
# <a href="https://colab.research.google.com/github/aditya-saurabh/generative-adversial-network/blob/master/CycleGAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importing libraries
import numpy as np
import tensorflow as tf
import tensorflow_addons as tfa
import matplotlib.pyplot as plt

# %%
# defining discriminator model

def discriminator(image_shape):
  # weight initialization for layers
  init = tf.keras.initializers.RandomNormal(stddev=0.02)

  # input layer
  input_layer = tf.keras.layers.Input(shape=image_shape)

  # C64
  d = tf.keras.layers.Conv2D(64, (4,4), (2,2), padding='same', kernel_initializer=init)(input_layer)
  d = tf.keras.layers.LeakyReLU(alpha=0.2)(d)

  # C128
  d = tf.keras.layers.Conv2D(128, (4,4), (2,2), padding='same', kernel_initializer=init)(d)
  d = tfa.layers.InstanceNormalization(axis=-1)(d)
  d = tf.keras.layers.LeakyReLU(alpha=0.2)(d)

  # C256
  d = tf.keras.layers.Conv2D(256, (4,4), (2,2), padding='same', kernel_initializer=init)(d)
  d = tfa.layers.InstanceNormalization(axis=-1)(d)
  d = tf.keras.layers.LeakyReLU(alpha=0.2)(d)

  # C512
  d = tf.keras.layers.Conv2D(512, (4,4), (2,2), padding='same', kernel_initializer=init)(d)
  d = tfa.layers.InstanceNormalization(axis=-1)(d)
  d = tf.keras.layers.LeakyReLU(alpha=0.2)(d)

  # C512 - second last layer
  d = tf.keras.layers.Conv2D(512, (4,4), (1,1), padding='same', kernel_initializer=init)(d)
  d = tfa.layers.InstanceNormalization(axis=-1)(d)
  d = tf.keras.layers.LeakyReLU(alpha=0.2)(d)

  # patch layer -- last layer
  patch_out = tf.keras.layers.Conv2D(1, (4,4), (1,1), padding='same', kernel_initializer=init)(d)

  model = tf.keras.Model(input_layer, patch_out)

  # compiling the model
  opt = tf.keras.optimizers.Adam(lr=0.0002, beta_1=0.5)
  model.compile(optimizer=opt, loss='mse', loss_weights=[0.5])

  return model

# %%
# printing model summary of discriminator

image_shape = (256,256,3)
dis = discriminator(image_shape)
dis.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 256, 256, 3)]     0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 128, 128, 64)      3136
# _________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)   (None, 128, 128, 64)      0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 64, 64, 128)       131200
# _________________________________________________________________
# instance_normalization_12 (I (None, 64, 64, 128)       256
# _________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)   (None, 64, 64, 128)       0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 32, 32, 256)       524544
# _________________________________________________________________
# instance_normalization_13 (I (None, 32, 32, 256)       512
# _________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)   (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 16, 16, 512)       2097664
# _________________________________________________________________
# instance_normalization_14 (I (None, 16, 16, 512)       1024
# _________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)   (None, 16, 16, 512)       0
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 16, 16, 512)       4194816
# _________________________________________________________________
# instance_normalization_15 (I (None, 16, 16, 512)       1024
# _________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)   (None, 16, 16, 512)       0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 16, 16, 1)         8193
# =================================================================
# Total params: 6,962,369
# Trainable params: 6,962,369
# Non-trainable params: 0
# _________________________________________________________________

# %%
# defining a resnet block

def res_block(n_filter, input_layer):
  #weight initialization
  init = tf.keras.initializers.RandomNormal(stddev=0.02)

  #first layer convolutional layer
  g = tf.keras.layers.Conv2D(n_filter, (3,3), (1,1), padding='same', kernel_initializer=init)(input_layer)
  g = tfa.layers.InstanceNormalization(axis=-1)(g)
  g = tf.keras.layers.ReLU()(g)

  #second layer convolutional layer
  g = tf.keras.layers.Conv2D(n_filter, (3,3), (1,1), padding='same', kernel_initializer=init)(g)
  g = tfa.layers.InstanceNormalization(axis=-1)(g)
  
  #concatenating
  merged = tf.keras.layers.Concatenate()([g, input_layer])

  return merged

# %%
# define generator model

def generator(input_shape=(256,256,3), n_resnet=9):
  # weight initialization
  init = tf.keras.initializers.RandomNormal(stddev=0.02)

  # input layer
  input_layer = tf.keras.layers.Input(shape=input_shape)

  #C64-F7-S1-P'same' I ReLU
  g = tf.keras.layers.Conv2D(64, (7,7), padding='same', kernel_initializer=init)(input_layer)
  g = tfa.layers.InstanceNormalization(axis=-1)(g)
  g = tf.keras.layers.Activation('relu')(g)

  #C128-F3-S2-P'same' I ReLU
  g = tf.keras.layers.Conv2D(128, (3,3), (2,2),padding='same', kernel_initializer=init)(g)
  g = tfa.layers.InstanceNormalization(axis=-1)(g)
  g = tf.keras.layers.Activation('relu')(g)

  #C256-F3-S2-P'same' I ReLU
  g = tf.keras.layers.Conv2D(256, (3,3), (2,2), padding='same', kernel_initializer=init)(g)
  g = tfa.layers.InstanceNormalization(axis=-1)(g)
  g = tf.keras.layers.Activation('relu')(g)

  #Residual blocks
  for _ in range(n_resnet):
    g = res_block(256, g)
  
  #UpC128-F3-S2-P'same' I ReLU
  g = tf.keras.layers.Conv2DTranspose(128, (3,3), (2,2), padding='same', kernel_initializer=init)(g)
  g = tfa.layers.InstanceNormalization(axis=-1)(g)
  g = tf.keras.layers.Activation('relu')(g)

  #UpC64-F3-S2-P'same' I ReLU
  g = tf.keras.layers.Conv2DTranspose(64, (3,3), (2,2), padding='same', kernel_initializer=init)(g)
  g = tfa.layers.InstanceNormalization(axis=-1)(g)
  g = tf.keras.layers.Activation('relu')(g)

  #C3-F7-S0-P'same' I tanh
  g = tf.keras.layers.Conv2D(3, (7,7), padding='same', kernel_initializer=init)(g)
  g = tfa.layers.InstanceNormalization(axis=-1)(g)
  out_img = tf.keras.layers.Activation('tanh')(g)

  #model
  model = tf.keras.models.Model(input_layer, out_img)

  return model

# %%
# calling generator
gen = generator()

# printing the model summary
gen.summary()
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_11 (InputLayer)           [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 256, 256, 64) 9472        input_11[0][0]
# __________________________________________________________________________________________________
# instance_normalization_53 (Inst (None, 256, 256, 64) 128         conv2d_60[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 256, 256, 64) 0           instance_normalization_53[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 128, 128, 128 73856       activation_15[0][0]
# __________________________________________________________________________________________________
# instance_normalization_54 (Inst (None, 128, 128, 128 256         conv2d_61[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 128, 128, 128 0           instance_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 64, 64, 256)  295168      activation_16[0][0]
# __________________________________________________________________________________________________
# instance_normalization_55 (Inst (None, 64, 64, 256)  512         conv2d_62[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 64, 64, 256)  0           instance_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 64, 64, 256)  590080      activation_17[0][0]
# __________________________________________________________________________________________________
# instance_normalization_56 (Inst (None, 64, 64, 256)  512         conv2d_63[0][0]
# __________________________________________________________________________________________________
# re_lu_10 (ReLU)                 (None, 64, 64, 256)  0           instance_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 64, 64, 256)  590080      re_lu_10[0][0]
# __________________________________________________________________________________________________
# instance_normalization_57 (Inst (None, 64, 64, 256)  512         conv2d_64[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 64, 64, 512)  0           instance_normalization_57[0][0]
#                                                                  activation_17[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 64, 64, 256)  1179904     concatenate_10[0][0]
# __________________________________________________________________________________________________
# instance_normalization_58 (Inst (None, 64, 64, 256)  512         conv2d_65[0][0]
# __________________________________________________________________________________________________
# re_lu_11 (ReLU)                 (None, 64, 64, 256)  0           instance_normalization_58[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 64, 64, 256)  590080      re_lu_11[0][0]
# __________________________________________________________________________________________________
# instance_normalization_59 (Inst (None, 64, 64, 256)  512         conv2d_66[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 64, 64, 768)  0           instance_normalization_59[0][0]
#                                                                  concatenate_10[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 64, 64, 256)  1769728     concatenate_11[0][0]
# __________________________________________________________________________________________________
# instance_normalization_60 (Inst (None, 64, 64, 256)  512         conv2d_67[0][0]
# __________________________________________________________________________________________________
# re_lu_12 (ReLU)                 (None, 64, 64, 256)  0           instance_normalization_60[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 64, 64, 256)  590080      re_lu_12[0][0]
# __________________________________________________________________________________________________
# instance_normalization_61 (Inst (None, 64, 64, 256)  512         conv2d_68[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 64, 64, 1024) 0           instance_normalization_61[0][0]
#                                                                  concatenate_11[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 64, 64, 256)  2359552     concatenate_12[0][0]
# __________________________________________________________________________________________________
# instance_normalization_62 (Inst (None, 64, 64, 256)  512         conv2d_69[0][0]
# __________________________________________________________________________________________________
# re_lu_13 (ReLU)                 (None, 64, 64, 256)  0           instance_normalization_62[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 64, 64, 256)  590080      re_lu_13[0][0]
# __________________________________________________________________________________________________
# instance_normalization_63 (Inst (None, 64, 64, 256)  512         conv2d_70[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 64, 64, 1280) 0           instance_normalization_63[0][0]
#                                                                  concatenate_12[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 64, 64, 256)  2949376     concatenate_13[0][0]
# __________________________________________________________________________________________________
# instance_normalization_64 (Inst (None, 64, 64, 256)  512         conv2d_71[0][0]
# __________________________________________________________________________________________________
# re_lu_14 (ReLU)                 (None, 64, 64, 256)  0           instance_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, 64, 64, 256)  590080      re_lu_14[0][0]
# __________________________________________________________________________________________________
# instance_normalization_65 (Inst (None, 64, 64, 256)  512         conv2d_72[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 64, 64, 1536) 0           instance_normalization_65[0][0]
#                                                                  concatenate_13[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, 64, 64, 256)  3539200     concatenate_14[0][0]
# __________________________________________________________________________________________________
# instance_normalization_66 (Inst (None, 64, 64, 256)  512         conv2d_73[0][0]
# __________________________________________________________________________________________________
# re_lu_15 (ReLU)                 (None, 64, 64, 256)  0           instance_normalization_66[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, 64, 64, 256)  590080      re_lu_15[0][0]
# __________________________________________________________________________________________________
# instance_normalization_67 (Inst (None, 64, 64, 256)  512         conv2d_74[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 64, 64, 1792) 0           instance_normalization_67[0][0]
#                                                                  concatenate_14[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 64, 64, 256)  4129024     concatenate_15[0][0]
# __________________________________________________________________________________________________
# instance_normalization_68 (Inst (None, 64, 64, 256)  512         conv2d_75[0][0]
# __________________________________________________________________________________________________
# re_lu_16 (ReLU)                 (None, 64, 64, 256)  0           instance_normalization_68[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 64, 64, 256)  590080      re_lu_16[0][0]
# __________________________________________________________________________________________________
# instance_normalization_69 (Inst (None, 64, 64, 256)  512         conv2d_76[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 64, 64, 2048) 0           instance_normalization_69[0][0]
#                                                                  concatenate_15[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 64, 64, 256)  4718848     concatenate_16[0][0]
# __________________________________________________________________________________________________
# instance_normalization_70 (Inst (None, 64, 64, 256)  512         conv2d_77[0][0]
# __________________________________________________________________________________________________
# re_lu_17 (ReLU)                 (None, 64, 64, 256)  0           instance_normalization_70[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 64, 64, 256)  590080      re_lu_17[0][0]
# __________________________________________________________________________________________________
# instance_normalization_71 (Inst (None, 64, 64, 256)  512         conv2d_78[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 64, 64, 2304) 0           instance_normalization_71[0][0]
#                                                                  concatenate_16[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 64, 64, 256)  5308672     concatenate_17[0][0]
# __________________________________________________________________________________________________
# instance_normalization_72 (Inst (None, 64, 64, 256)  512         conv2d_79[0][0]
# __________________________________________________________________________________________________
# re_lu_18 (ReLU)                 (None, 64, 64, 256)  0           instance_normalization_72[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 64, 64, 256)  590080      re_lu_18[0][0]
# __________________________________________________________________________________________________
# instance_normalization_73 (Inst (None, 64, 64, 256)  512         conv2d_80[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 64, 64, 2560) 0           instance_normalization_73[0][0]
#                                                                  concatenate_17[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 128, 128, 128 2949248     concatenate_18[0][0]
# __________________________________________________________________________________________________
# instance_normalization_74 (Inst (None, 128, 128, 128 256         conv2d_transpose_2[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 128, 128, 128 0           instance_normalization_74[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 256, 256, 64) 73792       activation_18[0][0]
# __________________________________________________________________________________________________
# instance_normalization_75 (Inst (None, 256, 256, 64) 128         conv2d_transpose_3[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 256, 256, 64) 0           instance_normalization_75[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 256, 256, 3)  9411        activation_19[0][0]
# __________________________________________________________________________________________________
# instance_normalization_76 (Inst (None, 256, 256, 3)  6           conv2d_81[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 256, 256, 3)  0           instance_normalization_76[0][0]
# ==================================================================================================
# Total params: 35,276,553
# Trainable params: 35,276,553
# Non-trainable params: 0
# __________________________________________________________________________________________________
